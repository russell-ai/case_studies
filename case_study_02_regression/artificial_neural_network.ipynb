# %% [markdown]
# # Artificial Neural Network
# Combined Cycle Power Plant Data Set
# url: https://archive.ics.uci.edu/ml/datasets/combined+cycle+power+plant

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.3.1'

# %% [markdown]
# ## Part 1 - Data Preprocessing
# ### Importing the dataset

# %%
df = pd.read_excel("..\\datasets\\UCI_PowerPlant.xlsx")
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %% [markdown]
# ### Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Part 2 - Building the ANN
# ### Initializing the ANN

# %%
model = tf.keras.models.Sequential()

# %% [markdown]
# ### Adding the input layer and the first hidden layer

# %%
model.add(tf.keras.layers.Dense(units=6, activation="relu"))

# %% [markdown]
# ### Adding the second hidden layer

# %%
model.add(tf.keras.layers.Dense(units=6, activation="relu"))

# %% [markdown]
# ### Adding the output layer

# %%
model.add(tf.keras.layers.Dense(units=1))

# %% [markdown]
# ## Part 3 - Compiling & Training the ANN
# ### Compiling the ANN

# %%
model.compile(optimizer="adam", loss="mean_squared_error")

# %% [markdown]
# ### Training the ANN model on the Training set

# %%
model.fit(X_train,y_train, batch_size=32, epochs=51)
# Out:
# Epoch 1/51
# 240/240 [==============================] - 1s 3ms/step - loss: 86014.2891
# Epoch 2/51
# 240/240 [==============================] - 1s 4ms/step - loss: 382.9156
# Epoch 3/51
# 240/240 [==============================] - 1s 4ms/step - loss: 361.9716
# Epoch 4/51
# 240/240 [==============================] - 1s 3ms/step - loss: 221.5503
# Epoch 5/51
# 240/240 [==============================] - 1s 3ms/step - loss: 114.0064
# Epoch 6/51
# 240/240 [==============================] - 1s 4ms/step - loss: 91.1928
# Epoch 7/51
# 240/240 [==============================] - 1s 4ms/step - loss: 79.0013
# Epoch 8/51
# 240/240 [==============================] - 1s 3ms/step - loss: 70.2670
# Epoch 9/51
# 240/240 [==============================] - 1s 3ms/step - loss: 63.1435
# Epoch 10/51
# 240/240 [==============================] - 1s 3ms/step - loss: 57.2834
# Epoch 11/51
# 240/240 [==============================] - 1s 5ms/step - loss: 52.5095
# Epoch 12/51
# 240/240 [==============================] - 1s 4ms/step - loss: 48.3877
# Epoch 13/51
# 240/240 [==============================] - 1s 3ms/step - loss: 45.2367
# Epoch 14/51
# 240/240 [==============================] - 1s 3ms/step - loss: 42.7600
# Epoch 15/51
# 240/240 [==============================] - 1s 5ms/step - loss: 40.6171
# Epoch 16/51
# 240/240 [==============================] - 1s 4ms/step - loss: 38.6494
# Epoch 17/51
# 240/240 [==============================] - 1s 4ms/step - loss: 37.3837
# Epoch 18/51
# 240/240 [==============================] - 1s 4ms/step - loss: 35.9545
# Epoch 19/51
#  - ETA: 0s - loss: 35.7841
# Epoch 20/51
#  - ETA: 0s - loss: 33.9537
# Epoch 21/51
# 240/240 [==============================] - 2s 8ms/step - loss: 33.1490
# Epoch 22/51
# 240/240 [==============================] - 1s 5ms/step - loss: 32.2376
# Epoch 23/51
# 240/240 [==============================] - 1s 4ms/step - loss: 31.1478
# Epoch 24/51
# 240/240 [==============================] - 1s 4ms/step - loss: 31.0701
# Epoch 25/51
# 240/240 [==============================] - 1s 4ms/step - loss: 29.9711
# Epoch 26/51
# 240/240 [==============================] - 1s 4ms/step - loss: 29.6632
# Epoch 27/51
# 240/240 [==============================] - 1s 4ms/step - loss: 29.0143
# Epoch 28/51
# 240/240 [==============================] - 1s 5ms/step - loss: 28.6335
# Epoch 29/51
# 240/240 [==============================] - 1s 6ms/step - loss: 28.6541
# Epoch 30/51
#  - ETA: 0s - loss: 28.0608
# Epoch 31/51
# 240/240 [==============================] - 1s 4ms/step - loss: 28.2256
# Epoch 32/51
# 240/240 [==============================] - 1s 4ms/step - loss: 28.0126
# Epoch 33/51
# 240/240 [==============================] - 1s 4ms/step - loss: 26.9997
# Epoch 34/51
# 240/240 [==============================] - 1s 3ms/step - loss: 28.6106
# Epoch 35/51
# 240/240 [==============================] - 1s 4ms/step - loss: 26.9967
# Epoch 36/51
# 240/240 [==============================] - 1s 3ms/step - loss: 28.0107
# Epoch 37/51
# 240/240 [==============================] - 1s 4ms/step - loss: 27.3508
# Epoch 38/51
# 240/240 [==============================] - 1s 4ms/step - loss: 27.4246
# Epoch 39/51
# 240/240 [==============================] - 1s 4ms/step - loss: 27.7602
# Epoch 40/51
# 240/240 [==============================] - 1s 3ms/step - loss: 27.8732
# Epoch 41/51
# 240/240 [==============================] - 1s 4ms/step - loss: 27.6623
# Epoch 42/51
# 240/240 [==============================] - 1s 3ms/step - loss: 27.2789
# Epoch 43/51
# 240/240 [==============================] - 1s 4ms/step - loss: 27.2871
# Epoch 44/51
#  - ETA: 0s - loss: 28.8472
# Epoch 45/51
# 240/240 [==============================] - 1s 4ms/step - loss: 26.6705
# Epoch 46/51
# 240/240 [==============================] - 1s 3ms/step - loss: 27.6033
# Epoch 47/51
#  - ETA: 0s - loss: 26.7412
# Epoch 48/51
#  - ETA: 0s - loss: 28.8480
# Epoch 49/51
# 240/240 [==============================] - 1s 4ms/step - loss: 27.5254
# Epoch 50/51
# 240/240 [==============================] - 1s 4ms/step - loss: 27.5605
# Epoch 51/51
# 240/240 [==============================] - 1s 3ms/step - loss: 26.7715

# %% [markdown]
# ### Predicting the results of the Test set

# %%
y_pred = model.predict(X_test)
np.set_printoptions(precision=2)
result = np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1)
print(result)
# Out:
# [[429.92 431.23]
#  [461.   460.01]
#  [464.54 461.14]
#  ...
#  [471.7  473.26]
#  [438.64 438.  ]
#  [457.79 463.28]]
